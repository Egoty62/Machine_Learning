# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
# Out:
# C:\Users\xodud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fmri = sns.load_dataset("fmri") # fmri : 기능정 자기 공명영상, 혈류와 관련된 변화를 감지하여 뇌 활동을 측정한 데이터
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.set_style("whitegrid")
sns.lineplot(x= "timepoint", y= "signal", data = fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
fmri.sample(n= 10, random_state= 1)
# Out:
#     subject  timepoint event    region    signal
# 806      s6         18   cue  parietal  0.019532
# 691      s5         15   cue   frontal -0.019507
# 148      s5          8  stim  parietal  0.006805
# 676     s13          0   cue  parietal -0.018394
# 156     s11          7  stim  parietal  0.254042
# 27       s1         17  stim  parietal -0.038021
# 200     s11          4  stim  parietal  0.087175
# 262      s3          0  stim  parietal -0.008576
# 94       s4         12  stim  parietal -0.090036
# 339      s4          5  stim   frontal  0.455575

# %%
sns.lineplot(x= "timepoint", y= "signal", data = fmri, hue= "region")
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
tips = sns.load_dataset("tips")
sns.regplot(x= "total_bill", y= "tip", data = tips, x_ci = 95)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x= "total_bill", y= "tip", data = tips, x_ci = 5)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x= "smoker", data = tips, hue = "day")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.barplot(x= "day", y= "total_bill", data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set(style= "ticks", color_codes= True)
tips = sns.load_dataset("tips")
pivot_df = tips.pivot_table(index= "sex", columns= "day",
                            values= "total_bill", aggfunc= "sum")
pivot_df.T.plot.bar(stacked= True, figsize= (10, 7))
# Out:
# <Axes: xlabel='day'>

# %%
N = 5
ind = np.arange(N)
width = 0.35

data_example = np.random.random_integers(0, 100, size= 50).reshape(-1, 5)
print(data_example)
# Out:
# [[49 56 49 38 69]
#  [53 10 18 83 22]
#  [42 97 33 78 39]
#  [28 85 38 58 46]
#  [51 95 86 22  4]
#  [53 32 36 24 87]
#  [64 99 91  0 84]
#  [13 76 30 41 39]
#  [51 14 31 21 65]
#  [94 21 78 23 75]]
# C:\Users\xodud\AppData\Local\Temp\ipykernel_12172\288126920.py:5: DeprecationWarning: This function is deprecated. Please call randint(0, 100 + 1) instead
#   data_example = np.random.random_integers(0, 100, size= 50).reshape(-1, 5)

# %%
for idx in range(len(data_example)) :
    plt.bar(
        x = ind, height= data_example[idx],
        width= width, bottom= data_example[:idx].sum(axis= 0)
    )

plt.show()

# %%
df = sns.load_dataset("iris")
grid = sns.FacetGrid(data= df, col= "species")
grid.map(sns.scatterplot, "sepal_length", "sepal_width")

# %%
sns.set_style("whitegrid")
sns.violinplot(x= "species", y= "sepal_width", data= df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>
